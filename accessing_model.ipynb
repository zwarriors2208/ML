# %%
import pickle

# %%
import pandas as pd
import numpy as np

# %%
with open("Cases/Glass Identification/stack_gls.pkl", 'rb') as f:
    objload = pickle.load(f)

# %%
objload
# Out:
# StackingClassifier(estimators=[('KNN', KNeighborsClassifier()),
#                                ('NB', GaussianNB()),
#                                ('TREE',
#                                 DecisionTreeClassifier(max_depth=2,
#                                                        random_state=24)),
#                                ('SVM',
#                                 SVC(C=3.0, probability=True, random_state=24))],
#                    final_estimator=RandomForestClassifier(max_depth=5,
#                                                           n_estimators=50,
#                                                           random_state=24),
#                    passthrough=True)

# %% [markdown]
# ### unlabelled data

# %%
tst_glass = pd.read_csv("Cases/Glass Identification/tst_Glass.csv")
tst_glass
# Out:
#        RI    Na    Mg    Al     Si      K    Ca    Ba     Fe
# 0  1.5321  14.0  0.00  0.34  70.23  0.001   6.7  1.23  0.000
# 1  1.5212  15.0  3.00  1.23  75.90  0.100   7.0  0.00  0.440
# 2  1.5112  13.0  3.50  2.30  73.00  3.400  14.0  2.30  0.220
# 3  1.5000  12.4  1.23  3.22  74.22  4.500  10.0  3.10  0.100
# 4  1.5200  13.0  2.40  0.34  71.22  3.200   9.0  1.44  0.001
# 5  1.5100  16.0  2.70  4.00  70.00  2.000   6.0  2.90  0.890

# %%
objload.predict(tst_glass)
# Out:
# array(['headlamps', 'building_windows_non_float_processed',
#        'building_windows_non_float_processed', 'headlamps',
#        'building_windows_non_float_processed', 'containers'], dtype=object)

# %%
tst_glass['pred_type'] = objload.predict(tst_glass)
tst_glass
# Out:
#        RI    Na    Mg    Al     Si      K    Ca    Ba     Fe  \
# 0  1.5321  14.0  0.00  0.34  70.23  0.001   6.7  1.23  0.000
# 1  1.5212  15.0  3.00  1.23  75.90  0.100   7.0  0.00  0.440
# 2  1.5112  13.0  3.50  2.30  73.00  3.400  14.0  2.30  0.220
# 3  1.5000  12.4  1.23  3.22  74.22  4.500  10.0  3.10  0.100
# 4  1.5200  13.0  2.40  0.34  71.22  3.200   9.0  1.44  0.001
# 5  1.5100  16.0  2.70  4.00  70.00  2.000   6.0  2.90  0.890
#
#                               pred_type
# 0                             headlamps
# 1  building_windows_non_float_processed
# 2  building_windows_non_float_processed
# 3                             headlamps
# 4  building_windows_non_float_processed
# 5                            containers

# %%
list = [1,2,3,4,6,7,4,4,5,6,3,2,5,6,7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 list = [1,2,3,4,6,7,4,4,5,6,3,2,5,6,7]
# ----> 2 list[4, 8]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
list[1,4,6,7]
